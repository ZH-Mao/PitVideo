# %%
import torch

# 假设坐标点数据
coordinates = torch.rand(4, 8, 2)  # 生成随机坐标点数据
print("原始坐标点数据：")
print(coordinates)
# Out:
# 原始坐标点数据：
# tensor([[[0.9898, 0.3434],
#          [0.4003, 0.5530],
#          [0.4362, 0.6255],
#          [0.8312, 0.3758],
#          [0.7374, 0.8945],
#          [0.9662, 0.2805],
#          [0.7064, 0.4754],
#          [0.4369, 0.1114]],
#
#         [[0.6860, 0.4948],
#          [0.0143, 0.6310],
#          [0.1950, 0.9135],
#          [0.6703, 0.3602],
#          [0.6982, 0.7867],
#          [0.0480, 0.4581],
#          [0.5547, 0.8019],
#          [0.8164, 0.1122]],
#
#         [[0.6467, 0.8461],
#          [0.3278, 0.7205],
#          [0.5091, 0.6761],
#          [0.5458, 0.0164],
#          [0.2079, 0.8673],
#          [0.5851, 0.8008],
#          [0.9003, 0.4805],
#          [0.4145, 0.9831]],
#
#         [[0.2906, 0.7794],
#          [0.3135, 0.1837],
#          [0.2620, 0.0659],
#          [0.1996, 0.6167],
#          [0.5565, 0.6169],
#          [0.4620, 0.1017],
#          [0.3926, 0.4298],
#          [0.8840, 0.7423]]])

# %%
import numpy as np
# coordinates[0][1]=torch.from_numpy(np.array([0.5, 0.1]))
# print(coordinates)

# 将超出范围的坐标点值设为0
coordinates[(coordinates[:, :, 0] < 0) | (coordinates[:, :, 0] > 1) | (coordinates[:, :, 1] < 0) | (coordinates[:, :, 1] > 1)] = 0

print("\n处理后的坐标点数据：")
print(coordinates/torch.from_numpy(np.array([0.1, 0.01])))
# Out:
# 处理后的坐标点数据：
# tensor([[[ 9.8980, 34.3366],
#          [ 4.0034, 55.3043],
#          [ 4.3624, 62.5503],
#          [ 8.3117, 37.5811],
#          [ 7.3738, 89.4464],
#          [ 9.6625, 28.0533],
#          [ 7.0637, 47.5375],
#          [ 4.3689, 11.1392]],
#
#         [[ 6.8599, 49.4809],
#          [ 0.1429, 63.1041],
#          [ 1.9502, 91.3513],
#          [ 6.7027, 36.0201],
#          [ 6.9817, 78.6746],
#          [ 0.4800, 45.8088],
#          [ 5.5473, 80.1947],
#          [ 8.1639, 11.2237]],
#
#         [[ 6.4668, 84.6108],
#          [ 3.2783, 72.0501],
#          [ 5.0910, 67.6086],
#          [ 5.4577,  1.6386],
#          [ 2.0789, 86.7303],
#          [ 5.8510, 80.0760],
#          [ 9.0028, 48.0500],
#          [ 4.1447, 98.3085]],
#
#         [[ 2.9058, 77.9413],
#          [ 3.1345, 18.3746],
#          [ 2.6201,  6.5935],
#          [ 1.9955, 61.6724],
#          [ 5.5649, 61.6868],
#          [ 4.6201, 10.1695],
#          [ 3.9260, 42.9776],
# ...
